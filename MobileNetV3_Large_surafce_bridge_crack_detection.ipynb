# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman-Kr-Gupta/Surface_Bridge_crack_detection/blob/main/MobileNetV3_Large_surafce_bridge_crack_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf

# %%
train_dir = os.path.join('/content/drive/MyDrive/Crack_detection_DB/train')
validation_dir = os.path.join('/content/drive/MyDrive/Crack_detection_DB/valid')
test_dir = os.path.join('/content/drive/MyDrive/Crack_detection_DB/test')

BATCH_SIZE = 16
IMG_SIZE = (160,160)

train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir,
                                                            shuffle=True,
                                                            batch_size=BATCH_SIZE,
                                                            image_size=IMG_SIZE)
# Out:
# Found 628 files belonging to 2 classes.

# %%
validation_dataset = tf.keras.utils.image_dataset_from_directory(validation_dir,
                                                                 shuffle=True,
                                                                 batch_size=BATCH_SIZE,
                                                                 image_size=IMG_SIZE)
# Out:
# Found 208 files belonging to 2 classes.

# %%
test_dataset = tf.keras.utils.image_dataset_from_directory(test_dir,
                                                           shuffle=True,
                                                           batch_size=BATCH_SIZE,
                                                           image_size=IMG_SIZE)
# Out:
# Found 200 files belonging to 2 classes.

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
val_batches = tf.data.experimental.cardinality(validation_dataset)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches: 13
# Number of test batches: 13

# %% [markdown]
# # Configure Dataset Performance and Data Augumentation

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
])

# %%
for image, _ in train_dataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(12):
    ax = plt.subplot(3, 4, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %%
preprocess_input = tf.keras.applications.mobilenet_v3.preprocess_input

# %%
rescale = tf.keras.layers.Rescaling(1./127.5, offset=-1)

# %%
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.MobileNetV3Large(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 [==============================] - 0s 0us/step

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (16, 5, 5, 960)

# %%
base_model.trainable=False

# %%
base_model.summary()
# Out:
# Model: "MobilenetV3large"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 160, 160, 3  0           []
#                                 )]
#
#  rescaling_1 (Rescaling)        (None, 160, 160, 3)  0           ['input_1[0][0]']
#
#  Conv (Conv2D)                  (None, 80, 80, 16)   432         ['rescaling_1[0][0]']
#
#  Conv/BatchNorm (BatchNormaliza  (None, 80, 80, 16)  64          ['Conv[0][0]']
#  tion)
#
#  tf.__operators__.add (TFOpLamb  (None, 80, 80, 16)  0           ['Conv/BatchNorm[0][0]']
#  da)
#
#  re_lu (ReLU)                   (None, 80, 80, 16)   0           ['tf.__operators__.add[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 80, 80, 16)   0           ['re_lu[0][0]']
#
#  multiply (Multiply)            (None, 80, 80, 16)   0           ['Conv/BatchNorm[0][0]',
#                                                                   'tf.math.multiply[0][0]']
#
#  expanded_conv/depthwise (Depth  (None, 80, 80, 16)  144         ['multiply[0][0]']
#  wiseConv2D)
#
#  expanded_conv/depthwise/BatchN  (None, 80, 80, 16)  64          ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)
#
#  re_lu_1 (ReLU)                 (None, 80, 80, 16)   0           ['expanded_conv/depthwise/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 80, 80, 16)  256         ['re_lu_1[0][0]']
#
#  expanded_conv/project/BatchNor  (None, 80, 80, 16)  64          ['expanded_conv/project[0][0]']
#  m (BatchNormalization)
#
#  expanded_conv/Add (Add)        (None, 80, 80, 16)   0           ['multiply[0][0]',
#                                                                   'expanded_conv/project/BatchNorm
#                                                                  [0][0]']
#
#  expanded_conv_1/expand (Conv2D  (None, 80, 80, 64)  1024        ['expanded_conv/Add[0][0]']
#  )
#
#  expanded_conv_1/expand/BatchNo  (None, 80, 80, 64)  256         ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_2 (ReLU)                 (None, 80, 80, 64)   0           ['expanded_conv_1/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 81, 81, 64)  0           ['re_lu_2[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_1/depthwise (Dep  (None, 40, 40, 64)  576         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 40, 40, 64)  256         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_3 (ReLU)                 (None, 40, 40, 64)   0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 40, 40, 24)  1536        ['re_lu_3[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 40, 40, 24)  96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 40, 40, 72)  1728        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 40, 40, 72)  288         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_4 (ReLU)                 (None, 40, 40, 72)   0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 40, 40, 72)  648         ['re_lu_4[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 40, 40, 72)  288         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_5 (ReLU)                 (None, 40, 40, 72)   0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 40, 40, 24)  1728        ['re_lu_5[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 40, 40, 24)  96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 40, 40, 24)   0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 40, 40, 72)  1728        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 40, 40, 72)  288         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_6 (ReLU)                 (None, 40, 40, 72)   0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 43, 43, 72)  0           ['re_lu_6[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 20, 20, 72)  1800        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 20, 20, 72)  288         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_7 (ReLU)                 (None, 20, 20, 72)   0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    0           ['re_lu_7[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    1752        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    1800        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 1, 1, 72)    0           ['expanded_conv_3/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 1, 1, 72)     0           ['tf.__operators__.add_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 1, 1, 72)    0           ['re_lu_8[0][0]']
#  )
#
#  expanded_conv_3/squeeze_excite  (None, 20, 20, 72)  0           ['re_lu_7[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_1[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 20, 20, 40)  2880        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 20, 20, 40)  160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 20, 20, 120)  4800       ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 20, 20, 120)  480        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_9 (ReLU)                 (None, 20, 20, 120)  0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 20, 20, 120)  3000       ['re_lu_9[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 20, 20, 120)  480        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_10 (ReLU)                (None, 20, 20, 120)  0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_10[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 1, 1, 120)   0           ['expanded_conv_4/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_11 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 1, 1, 120)   0           ['re_lu_11[0][0]']
#  )
#
#  expanded_conv_4/squeeze_excite  (None, 20, 20, 120)  0          ['re_lu_10[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_2[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 20, 20, 40)  4800        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 20, 20, 40)  160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 20, 20, 40)   0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 20, 20, 120)  4800       ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 20, 20, 120)  480        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_12 (ReLU)                (None, 20, 20, 120)  0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 20, 20, 120)  3000       ['re_lu_12[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 20, 20, 120)  480        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_13 (ReLU)                (None, 20, 20, 120)  0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_13[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 1, 1, 120)   0           ['expanded_conv_5/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_14 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_3[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 1, 1, 120)   0           ['re_lu_14[0][0]']
#  )
#
#  expanded_conv_5/squeeze_excite  (None, 20, 20, 120)  0          ['re_lu_13[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_3[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 20, 20, 40)  4800        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 20, 20, 40)  160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 20, 20, 40)   0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 20, 20, 240)  9600       ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 20, 20, 240)  960        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_4 (TFOpLa  (None, 20, 20, 240)  0          ['expanded_conv_6/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_15 (ReLU)                (None, 20, 20, 240)  0           ['tf.__operators__.add_4[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 20, 20, 240)  0          ['re_lu_15[0][0]']
#  )
#
#  multiply_1 (Multiply)          (None, 20, 20, 240)  0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_4[0][0]']
#
#  expanded_conv_6/depthwise/pad   (None, 21, 21, 240)  0          ['multiply_1[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_6/depthwise (Dep  (None, 10, 10, 240)  2160       ['expanded_conv_6/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_6/depthwise/Batc  (None, 10, 10, 240)  960        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 10, 10, 240)  0          ['expanded_conv_6/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_16 (ReLU)                (None, 10, 10, 240)  0           ['tf.__operators__.add_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 10, 10, 240)  0          ['re_lu_16[0][0]']
#  )
#
#  multiply_2 (Multiply)          (None, 10, 10, 240)  0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_5[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 10, 10, 80)  19200       ['multiply_2[0][0]']
#  D)
#
#  expanded_conv_6/project/BatchN  (None, 10, 10, 80)  320         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 10, 10, 200)  16000      ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 10, 10, 200)  800        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_6 (TFOpLa  (None, 10, 10, 200)  0          ['expanded_conv_7/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_17 (ReLU)                (None, 10, 10, 200)  0           ['tf.__operators__.add_6[0][0]']
#
#  tf.math.multiply_6 (TFOpLambda  (None, 10, 10, 200)  0          ['re_lu_17[0][0]']
#  )
#
#  multiply_3 (Multiply)          (None, 10, 10, 200)  0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_6[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 10, 10, 200)  1800       ['multiply_3[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 10, 10, 200)  800        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 10, 10, 200)  0          ['expanded_conv_7/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_18 (ReLU)                (None, 10, 10, 200)  0           ['tf.__operators__.add_7[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 10, 10, 200)  0          ['re_lu_18[0][0]']
#  )
#
#  multiply_4 (Multiply)          (None, 10, 10, 200)  0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_7[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 10, 10, 80)  16000       ['multiply_4[0][0]']
#  D)
#
#  expanded_conv_7/project/BatchN  (None, 10, 10, 80)  320         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 10, 10, 80)   0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 10, 10, 184)  14720      ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 10, 10, 184)  736        ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_8 (TFOpLa  (None, 10, 10, 184)  0          ['expanded_conv_8/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_19 (ReLU)                (None, 10, 10, 184)  0           ['tf.__operators__.add_8[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 10, 10, 184)  0          ['re_lu_19[0][0]']
#  )
#
#  multiply_5 (Multiply)          (None, 10, 10, 184)  0           ['expanded_conv_8/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  expanded_conv_8/depthwise (Dep  (None, 10, 10, 184)  1656       ['multiply_5[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_8/depthwise/Batc  (None, 10, 10, 184)  736        ['expanded_conv_8/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 10, 10, 184)  0          ['expanded_conv_8/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_20 (ReLU)                (None, 10, 10, 184)  0           ['tf.__operators__.add_9[0][0]']
#
#  tf.math.multiply_9 (TFOpLambda  (None, 10, 10, 184)  0          ['re_lu_20[0][0]']
#  )
#
#  multiply_6 (Multiply)          (None, 10, 10, 184)  0           ['expanded_conv_8/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_9[0][0]']
#
#  expanded_conv_8/project (Conv2  (None, 10, 10, 80)  14720       ['multiply_6[0][0]']
#  D)
#
#  expanded_conv_8/project/BatchN  (None, 10, 10, 80)  320         ['expanded_conv_8/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_8/Add (Add)      (None, 10, 10, 80)   0           ['expanded_conv_7/Add[0][0]',
#                                                                   'expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_9/expand (Conv2D  (None, 10, 10, 184)  14720      ['expanded_conv_8/Add[0][0]']
#  )
#
#  expanded_conv_9/expand/BatchNo  (None, 10, 10, 184)  736        ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_10 (TFOpL  (None, 10, 10, 184)  0          ['expanded_conv_9/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_21 (ReLU)                (None, 10, 10, 184)  0           ['tf.__operators__.add_10[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 10, 10, 184)  0          ['re_lu_21[0][0]']
#  a)
#
#  multiply_7 (Multiply)          (None, 10, 10, 184)  0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_10[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 10, 10, 184)  1656       ['multiply_7[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 10, 10, 184)  736        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_11 (TFOpL  (None, 10, 10, 184)  0          ['expanded_conv_9/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_22 (ReLU)                (None, 10, 10, 184)  0           ['tf.__operators__.add_11[0][0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, 10, 10, 184)  0          ['re_lu_22[0][0]']
#  a)
#
#  multiply_8 (Multiply)          (None, 10, 10, 184)  0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_11[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 10, 10, 80)  14720       ['multiply_8[0][0]']
#  D)
#
#  expanded_conv_9/project/BatchN  (None, 10, 10, 80)  320         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 10, 10, 80)   0           ['expanded_conv_8/Add[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 10, 10, 480)  38400      ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 10, 10, 480)  1920       ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_12 (TFOpL  (None, 10, 10, 480)  0          ['expanded_conv_10/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_23 (ReLU)                (None, 10, 10, 480)  0           ['tf.__operators__.add_12[0][0]']
#
#  tf.math.multiply_12 (TFOpLambd  (None, 10, 10, 480)  0          ['re_lu_23[0][0]']
#  a)
#
#  multiply_9 (Multiply)          (None, 10, 10, 480)  0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_12[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 10, 10, 480)  4320       ['multiply_9[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 10, 10, 480)  1920       ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 10, 10, 480)  0          ['expanded_conv_10/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_24 (ReLU)                (None, 10, 10, 480)  0           ['tf.__operators__.add_13[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None, 10, 10, 480)  0          ['re_lu_24[0][0]']
#  a)
#
#  multiply_10 (Multiply)         (None, 10, 10, 480)  0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_13[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 480)   0           ['multiply_10[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 120)   57720       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 120)   0           ['expanded_conv_10/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 480)   58080       ['expanded_conv_10/squeeze_excite
# ...
#
#  expanded_conv_13/expand (Conv2  (None, 5, 5, 960)   153600      ['expanded_conv_12/project/BatchN
#  D)                                                              orm[0][0]']
#
#  expanded_conv_13/expand/BatchN  (None, 5, 5, 960)   3840        ['expanded_conv_13/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_21 (TFOpL  (None, 5, 5, 960)   0           ['expanded_conv_13/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_32 (ReLU)                (None, 5, 5, 960)    0           ['tf.__operators__.add_21[0][0]']
#
#  tf.math.multiply_21 (TFOpLambd  (None, 5, 5, 960)   0           ['re_lu_32[0][0]']
#  a)
#
#  multiply_15 (Multiply)         (None, 5, 5, 960)    0           ['expanded_conv_13/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_21[0][0]']
#
#  expanded_conv_13/depthwise (De  (None, 5, 5, 960)   24000       ['multiply_15[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_13/depthwise/Bat  (None, 5, 5, 960)   3840        ['expanded_conv_13/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_22 (TFOpL  (None, 5, 5, 960)   0           ['expanded_conv_13/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_33 (ReLU)                (None, 5, 5, 960)    0           ['tf.__operators__.add_22[0][0]']
#
#  tf.math.multiply_22 (TFOpLambd  (None, 5, 5, 960)   0           ['re_lu_33[0][0]']
#  a)
#
#  multiply_16 (Multiply)         (None, 5, 5, 960)    0           ['expanded_conv_13/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_22[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_16[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_13/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_13/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_13/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_23 (TFOpL  (None, 1, 1, 960)   0           ['expanded_conv_13/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_34 (ReLU)                (None, 1, 1, 960)    0           ['tf.__operators__.add_23[0][0]']
#
#  tf.math.multiply_23 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_34[0][0]']
#  a)
#
#  expanded_conv_13/squeeze_excit  (None, 5, 5, 960)   0           ['multiply_16[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_23[0][0]']
#
#  expanded_conv_13/project (Conv  (None, 5, 5, 160)   153600      ['expanded_conv_13/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_13/project/Batch  (None, 5, 5, 160)   640         ['expanded_conv_13/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_13/Add (Add)     (None, 5, 5, 160)    0           ['expanded_conv_12/project/BatchN
#                                                                  orm[0][0]',
#                                                                   'expanded_conv_13/project/BatchN
#                                                                  orm[0][0]']
#
#  expanded_conv_14/expand (Conv2  (None, 5, 5, 960)   153600      ['expanded_conv_13/Add[0][0]']
#  D)
#
#  expanded_conv_14/expand/BatchN  (None, 5, 5, 960)   3840        ['expanded_conv_14/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_24 (TFOpL  (None, 5, 5, 960)   0           ['expanded_conv_14/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_35 (ReLU)                (None, 5, 5, 960)    0           ['tf.__operators__.add_24[0][0]']
#
#  tf.math.multiply_24 (TFOpLambd  (None, 5, 5, 960)   0           ['re_lu_35[0][0]']
#  a)
#
#  multiply_17 (Multiply)         (None, 5, 5, 960)    0           ['expanded_conv_14/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_24[0][0]']
#
#  expanded_conv_14/depthwise (De  (None, 5, 5, 960)   24000       ['multiply_17[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_14/depthwise/Bat  (None, 5, 5, 960)   3840        ['expanded_conv_14/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_25 (TFOpL  (None, 5, 5, 960)   0           ['expanded_conv_14/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_36 (ReLU)                (None, 5, 5, 960)    0           ['tf.__operators__.add_25[0][0]']
#
#  tf.math.multiply_25 (TFOpLambd  (None, 5, 5, 960)   0           ['re_lu_36[0][0]']
#  a)
#
#  multiply_18 (Multiply)         (None, 5, 5, 960)    0           ['expanded_conv_14/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_25[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_18[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_14/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_14/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_14/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_26 (TFOpL  (None, 1, 1, 960)   0           ['expanded_conv_14/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_37 (ReLU)                (None, 1, 1, 960)    0           ['tf.__operators__.add_26[0][0]']
#
#  tf.math.multiply_26 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_37[0][0]']
#  a)
#
#  expanded_conv_14/squeeze_excit  (None, 5, 5, 960)   0           ['multiply_18[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_26[0][0]']
#
#  expanded_conv_14/project (Conv  (None, 5, 5, 160)   153600      ['expanded_conv_14/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_14/project/Batch  (None, 5, 5, 160)   640         ['expanded_conv_14/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_14/Add (Add)     (None, 5, 5, 160)    0           ['expanded_conv_13/Add[0][0]',
#                                                                   'expanded_conv_14/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 5, 5, 960)    153600      ['expanded_conv_14/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 5, 5, 960)   3840        ['Conv_1[0][0]']
#  zation)
#
#  tf.__operators__.add_27 (TFOpL  (None, 5, 5, 960)   0           ['Conv_1/BatchNorm[0][0]']
#  ambda)
#
#  re_lu_38 (ReLU)                (None, 5, 5, 960)    0           ['tf.__operators__.add_27[0][0]']
#
#  tf.math.multiply_27 (TFOpLambd  (None, 5, 5, 960)   0           ['re_lu_38[0][0]']
#  a)
#
#  multiply_19 (Multiply)         (None, 5, 5, 960)    0           ['Conv_1/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_27[0][0]']
#
# ==================================================================================================
# Total params: 2,996,352
# Trainable params: 0
# Non-trainable params: 2,996,352
# __________________________________________________________________________________________________

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (16, 960)

# %%
prediction_layer = tf.keras.layers.Dense(1)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (16, 1)

# %%
inputs = tf.keras.Input(shape=(160,160, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
len(model.trainable_variables)
# Out:
# 2

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  sequential (Sequential)     (None, 160, 160, 3)       0
#
#  MobilenetV3large (Functiona  (None, 5, 5, 960)        2996352
#  l)
#
#  global_average_pooling2d (G  (None, 960)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 960)               0
#
#  dense (Dense)               (None, 1)                 961
#
# =================================================================
# Total params: 2,997,313
# Trainable params: 961
# Non-trainable params: 2,996,352
# _________________________________________________________________

# %%
initial_epochs = 100

loss0, accuracy0 = model.evaluate(validation_dataset)
# Out:
# 13/13 [==============================] - 36s 920ms/step - loss: 1.3675 - accuracy: 0.4087

# %%
print("initial loss: {:.2f}".format(loss0))
print("initial accuracy: {:.2f}".format(accuracy0))
# Out:
# initial loss: 1.37
# initial accuracy: 0.41

# %%
history = model.fit(train_dataset,
                    epochs=initial_epochs,
                    validation_data=validation_dataset)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 52s 1s/step - loss: 1.1710 - accuracy: 0.3551 - val_loss: 1.1566 - val_accuracy: 0.4423
# Epoch 2/100
# 40/40 [==============================] - 20s 497ms/step - loss: 1.0233 - accuracy: 0.4013 - val_loss: 0.9838 - val_accuracy: 0.5096
# Epoch 3/100
# 40/40 [==============================] - 28s 694ms/step - loss: 0.9070 - accuracy: 0.4411 - val_loss: 0.8413 - val_accuracy: 0.5385
# Epoch 4/100
# 40/40 [==============================] - 23s 570ms/step - loss: 0.7913 - accuracy: 0.5446 - val_loss: 0.7255 - val_accuracy: 0.5962
# Epoch 5/100
# 40/40 [==============================] - 20s 493ms/step - loss: 0.7438 - accuracy: 0.5525 - val_loss: 0.6247 - val_accuracy: 0.6923
# Epoch 6/100
# 40/40 [==============================] - 25s 623ms/step - loss: 0.6414 - accuracy: 0.6752 - val_loss: 0.5470 - val_accuracy: 0.7548
# Epoch 7/100
# 40/40 [==============================] - 18s 445ms/step - loss: 0.6116 - accuracy: 0.6863 - val_loss: 0.4797 - val_accuracy: 0.7933
# Epoch 8/100
# 40/40 [==============================] - 19s 459ms/step - loss: 0.5331 - accuracy: 0.7596 - val_loss: 0.4236 - val_accuracy: 0.8558
# Epoch 9/100
# 40/40 [==============================] - 22s 557ms/step - loss: 0.4978 - accuracy: 0.7787 - val_loss: 0.3775 - val_accuracy: 0.8942
# Epoch 10/100
# 40/40 [==============================] - 19s 487ms/step - loss: 0.4554 - accuracy: 0.7882 - val_loss: 0.3389 - val_accuracy: 0.9231
# Epoch 11/100
# 40/40 [==============================] - 18s 445ms/step - loss: 0.4019 - accuracy: 0.8408 - val_loss: 0.3075 - val_accuracy: 0.9375
# Epoch 12/100
# 40/40 [==============================] - 18s 457ms/step - loss: 0.4140 - accuracy: 0.8169 - val_loss: 0.2796 - val_accuracy: 0.9423
# Epoch 13/100
# 40/40 [==============================] - 20s 492ms/step - loss: 0.3769 - accuracy: 0.8662 - val_loss: 0.2562 - val_accuracy: 0.9519
# Epoch 14/100
# 40/40 [==============================] - 20s 493ms/step - loss: 0.3583 - accuracy: 0.8678 - val_loss: 0.2363 - val_accuracy: 0.9567
# Epoch 15/100
# 40/40 [==============================] - 18s 444ms/step - loss: 0.3279 - accuracy: 0.9013 - val_loss: 0.2184 - val_accuracy: 0.9663
# Epoch 16/100
# 40/40 [==============================] - 19s 469ms/step - loss: 0.3052 - accuracy: 0.9013 - val_loss: 0.2025 - val_accuracy: 0.9663
# Epoch 17/100
# 40/40 [==============================] - 22s 555ms/step - loss: 0.3002 - accuracy: 0.9108 - val_loss: 0.1888 - val_accuracy: 0.9712
# Epoch 18/100
# 40/40 [==============================] - 20s 490ms/step - loss: 0.2871 - accuracy: 0.9188 - val_loss: 0.1766 - val_accuracy: 0.9760
# Epoch 19/100
# 40/40 [==============================] - 20s 490ms/step - loss: 0.2853 - accuracy: 0.8965 - val_loss: 0.1664 - val_accuracy: 0.9760
# Epoch 20/100
# 40/40 [==============================] - 20s 498ms/step - loss: 0.2548 - accuracy: 0.9283 - val_loss: 0.1575 - val_accuracy: 0.9760
# Epoch 21/100
# 40/40 [==============================] - 18s 452ms/step - loss: 0.2437 - accuracy: 0.9331 - val_loss: 0.1487 - val_accuracy: 0.9808
# Epoch 22/100
# 40/40 [==============================] - 19s 486ms/step - loss: 0.2467 - accuracy: 0.9220 - val_loss: 0.1412 - val_accuracy: 0.9808
# Epoch 23/100
# 40/40 [==============================] - 19s 463ms/step - loss: 0.2209 - accuracy: 0.9315 - val_loss: 0.1346 - val_accuracy: 0.9808
# Epoch 24/100
# 40/40 [==============================] - 19s 484ms/step - loss: 0.2169 - accuracy: 0.9506 - val_loss: 0.1284 - val_accuracy: 0.9856
# 40/40 [==============================] - 19s 483ms/step - loss: 0.2202 - accuracy: 0.9236 - val_loss: 0.1227 - val_accuracy: 0.9856
# Epoch 26/100
# 40/40 [==============================] - 20s 492ms/step - loss: 0.2158 - accuracy: 0.9395 - val_loss: 0.1175 - val_accuracy: 0.9856
# Epoch 27/100
# 40/40 [==============================] - 18s 443ms/step - loss: 0.2028 - accuracy: 0.9427 - val_loss: 0.1133 - val_accuracy: 0.9856
# Epoch 28/100
# 40/40 [==============================] - 18s 457ms/step - loss: 0.1934 - accuracy: 0.9459 - val_loss: 0.1095 - val_accuracy: 0.9856
# Epoch 29/100
# 40/40 [==============================] - 18s 451ms/step - loss: 0.2061 - accuracy: 0.9395 - val_loss: 0.1059 - val_accuracy: 0.9856
# Epoch 30/100
# 40/40 [==============================] - 18s 437ms/step - loss: 0.1810 - accuracy: 0.9586 - val_loss: 0.1023 - val_accuracy: 0.9856
# Epoch 31/100
# 40/40 [==============================] - 18s 458ms/step - loss: 0.1807 - accuracy: 0.9522 - val_loss: 0.0989 - val_accuracy: 0.9856
# Epoch 32/100
# 40/40 [==============================] - 18s 444ms/step - loss: 0.1832 - accuracy: 0.9475 - val_loss: 0.0952 - val_accuracy: 0.9856
# Epoch 33/100
# 40/40 [==============================] - 20s 486ms/step - loss: 0.1850 - accuracy: 0.9411 - val_loss: 0.0925 - val_accuracy: 0.9856
# Epoch 34/100
# 40/40 [==============================] - 19s 483ms/step - loss: 0.1660 - accuracy: 0.9570 - val_loss: 0.0899 - val_accuracy: 0.9856
# Epoch 35/100
# 40/40 [==============================] - 26s 645ms/step - loss: 0.1765 - accuracy: 0.9459 - val_loss: 0.0867 - val_accuracy: 0.9856
# Epoch 36/100
# 40/40 [==============================] - 20s 491ms/step - loss: 0.1613 - accuracy: 0.9618 - val_loss: 0.0843 - val_accuracy: 0.9856
# Epoch 37/100
# 40/40 [==============================] - 20s 489ms/step - loss: 0.1673 - accuracy: 0.9490 - val_loss: 0.0820 - val_accuracy: 0.9856
# Epoch 38/100
# 40/40 [==============================] - 19s 485ms/step - loss: 0.1539 - accuracy: 0.9522 - val_loss: 0.0802 - val_accuracy: 0.9856
# Epoch 39/100
# 40/40 [==============================] - 19s 476ms/step - loss: 0.1617 - accuracy: 0.9427 - val_loss: 0.0788 - val_accuracy: 0.9856
# Epoch 40/100
# 40/40 [==============================] - 18s 430ms/step - loss: 0.1585 - accuracy: 0.9554 - val_loss: 0.0769 - val_accuracy: 0.9856
# Epoch 41/100
# 40/40 [==============================] - 18s 437ms/step - loss: 0.1616 - accuracy: 0.9506 - val_loss: 0.0753 - val_accuracy: 0.9856
# Epoch 42/100
# 40/40 [==============================] - 20s 489ms/step - loss: 0.1511 - accuracy: 0.9602 - val_loss: 0.0733 - val_accuracy: 0.9856
# Epoch 43/100
# 40/40 [==============================] - 19s 486ms/step - loss: 0.1618 - accuracy: 0.9522 - val_loss: 0.0718 - val_accuracy: 0.9856
# Epoch 44/100
# 40/40 [==============================] - 29s 725ms/step - loss: 0.1474 - accuracy: 0.9586 - val_loss: 0.0700 - val_accuracy: 0.9856
# Epoch 45/100
# 40/40 [==============================] - 23s 566ms/step - loss: 0.1427 - accuracy: 0.9490 - val_loss: 0.0688 - val_accuracy: 0.9856
# Epoch 46/100
# 40/40 [==============================] - 20s 507ms/step - loss: 0.1405 - accuracy: 0.9618 - val_loss: 0.0672 - val_accuracy: 0.9856
# Epoch 47/100
# 40/40 [==============================] - 19s 460ms/step - loss: 0.1386 - accuracy: 0.9586 - val_loss: 0.0661 - val_accuracy: 0.9856
# Epoch 48/100
# 40/40 [==============================] - 18s 437ms/step - loss: 0.1427 - accuracy: 0.9506 - val_loss: 0.0650 - val_accuracy: 0.9856
# Epoch 49/100
# 40/40 [==============================] - 18s 435ms/step - loss: 0.1381 - accuracy: 0.9602 - val_loss: 0.0641 - val_accuracy: 0.9856
# Epoch 50/100
# 40/40 [==============================] - 20s 488ms/step - loss: 0.1223 - accuracy: 0.9682 - val_loss: 0.0623 - val_accuracy: 0.9856
# Epoch 51/100
# 40/40 [==============================] - 20s 487ms/step - loss: 0.1395 - accuracy: 0.9570 - val_loss: 0.0610 - val_accuracy: 0.9856
# Epoch 52/100
# 40/40 [==============================] - 20s 494ms/step - loss: 0.1332 - accuracy: 0.9650 - val_loss: 0.0602 - val_accuracy: 0.9856
# Epoch 53/100
# 40/40 [==============================] - 18s 441ms/step - loss: 0.1135 - accuracy: 0.9666 - val_loss: 0.0586 - val_accuracy: 0.9856
# Epoch 54/100
# 40/40 [==============================] - 18s 440ms/step - loss: 0.1265 - accuracy: 0.9602 - val_loss: 0.0581 - val_accuracy: 0.9856
# Epoch 55/100
# 40/40 [==============================] - 20s 492ms/step - loss: 0.1310 - accuracy: 0.9618 - val_loss: 0.0576 - val_accuracy: 0.9856
# Epoch 56/100
# 40/40 [==============================] - 20s 495ms/step - loss: 0.1267 - accuracy: 0.9618 - val_loss: 0.0566 - val_accuracy: 0.9856
# Epoch 57/100
# 40/40 [==============================] - 20s 492ms/step - loss: 0.1226 - accuracy: 0.9682 - val_loss: 0.0553 - val_accuracy: 0.9856
# Epoch 58/100
# 40/40 [==============================] - 19s 464ms/step - loss: 0.1381 - accuracy: 0.9554 - val_loss: 0.0546 - val_accuracy: 0.9856
# Epoch 59/100
# 40/40 [==============================] - 22s 555ms/step - loss: 0.1205 - accuracy: 0.9650 - val_loss: 0.0536 - val_accuracy: 0.9856
# Epoch 60/100
# 40/40 [==============================] - 20s 499ms/step - loss: 0.1187 - accuracy: 0.9586 - val_loss: 0.0526 - val_accuracy: 0.9856
# Epoch 61/100
# 40/40 [==============================] - 24s 603ms/step - loss: 0.1262 - accuracy: 0.9586 - val_loss: 0.0514 - val_accuracy: 0.9856
# Epoch 62/100
# 40/40 [==============================] - 17s 435ms/step - loss: 0.1130 - accuracy: 0.9666 - val_loss: 0.0505 - val_accuracy: 0.9856
# Epoch 63/100
# 40/40 [==============================] - 18s 441ms/step - loss: 0.1192 - accuracy: 0.9682 - val_loss: 0.0499 - val_accuracy: 0.9856
# Epoch 64/100
# 40/40 [==============================] - 20s 493ms/step - loss: 0.1089 - accuracy: 0.9682 - val_loss: 0.0489 - val_accuracy: 0.9904
# Epoch 65/100
# 40/40 [==============================] - 20s 492ms/step - loss: 0.1147 - accuracy: 0.9697 - val_loss: 0.0483 - val_accuracy: 0.9856
# Epoch 66/100
# 40/40 [==============================] - 20s 490ms/step - loss: 0.1020 - accuracy: 0.9682 - val_loss: 0.0476 - val_accuracy: 0.9856
# Epoch 67/100
# 40/40 [==============================] - 19s 470ms/step - loss: 0.1256 - accuracy: 0.9618 - val_loss: 0.0472 - val_accuracy: 0.9856
# Epoch 68/100
# 40/40 [==============================] - 23s 567ms/step - loss: 0.1106 - accuracy: 0.9618 - val_loss: 0.0468 - val_accuracy: 0.9856
# Epoch 69/100
# 40/40 [==============================] - 20s 490ms/step - loss: 0.1074 - accuracy: 0.9697 - val_loss: 0.0463 - val_accuracy: 0.9856
# Epoch 70/100
# 40/40 [==============================] - 19s 468ms/step - loss: 0.1120 - accuracy: 0.9650 - val_loss: 0.0459 - val_accuracy: 0.9856
# Epoch 71/100
# 40/40 [==============================] - 18s 433ms/step - loss: 0.0982 - accuracy: 0.9713 - val_loss: 0.0455 - val_accuracy: 0.9856
# Epoch 72/100
# 40/40 [==============================] - 18s 433ms/step - loss: 0.1003 - accuracy: 0.9761 - val_loss: 0.0447 - val_accuracy: 0.9904
# Epoch 73/100
# 40/40 [==============================] - 18s 446ms/step - loss: 0.1200 - accuracy: 0.9618 - val_loss: 0.0447 - val_accuracy: 0.9856
# Epoch 74/100
# 40/40 [==============================] - 18s 450ms/step - loss: 0.1041 - accuracy: 0.9697 - val_loss: 0.0447 - val_accuracy: 0.9856
# Epoch 75/100
# 40/40 [==============================] - 18s 438ms/step - loss: 0.0997 - accuracy: 0.9682 - val_loss: 0.0441 - val_accuracy: 0.9856
# Epoch 76/100
# 40/40 [==============================] - 19s 485ms/step - loss: 0.1049 - accuracy: 0.9745 - val_loss: 0.0431 - val_accuracy: 0.9904
# Epoch 77/100
# 40/40 [==============================] - 20s 508ms/step - loss: 0.1026 - accuracy: 0.9682 - val_loss: 0.0425 - val_accuracy: 0.9904
# Epoch 78/100
# 40/40 [==============================] - 19s 467ms/step - loss: 0.1039 - accuracy: 0.9682 - val_loss: 0.0418 - val_accuracy: 0.9904
# Epoch 79/100
# 40/40 [==============================] - 22s 552ms/step - loss: 0.1183 - accuracy: 0.9682 - val_loss: 0.0413 - val_accuracy: 0.9904
# Epoch 80/100
# 40/40 [==============================] - 20s 490ms/step - loss: 0.1100 - accuracy: 0.9682 - val_loss: 0.0411 - val_accuracy: 0.9952
# Epoch 81/100
# 40/40 [==============================] - 20s 490ms/step - loss: 0.1106 - accuracy: 0.9666 - val_loss: 0.0412 - val_accuracy: 0.9904
# Epoch 82/100
# 40/40 [==============================] - 20s 491ms/step - loss: 0.0881 - accuracy: 0.9745 - val_loss: 0.0401 - val_accuracy: 0.9952
# Epoch 83/100
# 40/40 [==============================] - 19s 455ms/step - loss: 0.0980 - accuracy: 0.9682 - val_loss: 0.0392 - val_accuracy: 0.9952
# Epoch 84/100
# 40/40 [==============================] - 22s 561ms/step - loss: 0.0936 - accuracy: 0.9745 - val_loss: 0.0388 - val_accuracy: 0.9952
# Epoch 85/100
# 40/40 [==============================] - 20s 490ms/step - loss: 0.1039 - accuracy: 0.9729 - val_loss: 0.0380 - val_accuracy: 0.9952
# Epoch 86/100
# 40/40 [==============================] - 17s 425ms/step - loss: 0.1123 - accuracy: 0.9666 - val_loss: 0.0382 - val_accuracy: 0.9952
# Epoch 87/100
# 40/40 [==============================] - 18s 444ms/step - loss: 0.1006 - accuracy: 0.9729 - val_loss: 0.0379 - val_accuracy: 0.9952
# Epoch 88/100
# 40/40 [==============================] - 19s 485ms/step - loss: 0.1037 - accuracy: 0.9634 - val_loss: 0.0378 - val_accuracy: 0.9952
# Epoch 89/100
# 40/40 [==============================] - 18s 436ms/step - loss: 0.1035 - accuracy: 0.9697 - val_loss: 0.0375 - val_accuracy: 0.9952
# Epoch 90/100
# 40/40 [==============================] - 18s 439ms/step - loss: 0.1110 - accuracy: 0.9586 - val_loss: 0.0374 - val_accuracy: 0.9952
# Epoch 91/100
# 40/40 [==============================] - 17s 423ms/step - loss: 0.0909 - accuracy: 0.9745 - val_loss: 0.0374 - val_accuracy: 0.9952
# Epoch 92/100
# 40/40 [==============================] - 22s 561ms/step - loss: 0.0920 - accuracy: 0.9745 - val_loss: 0.0371 - val_accuracy: 0.9952
# Epoch 93/100
# 40/40 [==============================] - 18s 439ms/step - loss: 0.0862 - accuracy: 0.9729 - val_loss: 0.0367 - val_accuracy: 0.9952
# Epoch 94/100
# 40/40 [==============================] - 20s 489ms/step - loss: 0.1119 - accuracy: 0.9634 - val_loss: 0.0368 - val_accuracy: 0.9952
# Epoch 95/100
# 40/40 [==============================] - 20s 484ms/step - loss: 0.0959 - accuracy: 0.9697 - val_loss: 0.0365 - val_accuracy: 0.9952
# Epoch 96/100
# 40/40 [==============================] - 18s 433ms/step - loss: 0.0937 - accuracy: 0.9666 - val_loss: 0.0361 - val_accuracy: 0.9952
# Epoch 97/100
# 40/40 [==============================] - 23s 562ms/step - loss: 0.0965 - accuracy: 0.9713 - val_loss: 0.0353 - val_accuracy: 0.9952
# Epoch 98/100
# 40/40 [==============================] - 19s 486ms/step - loss: 0.0942 - accuracy: 0.9745 - val_loss: 0.0349 - val_accuracy: 0.9952
# Epoch 99/100
# 40/40 [==============================] - 19s 485ms/step - loss: 0.0787 - accuracy: 0.9825 - val_loss: 0.0346 - val_accuracy: 0.9952
# Epoch 100/100
# 40/40 [==============================] - 19s 486ms/step - loss: 0.0921 - accuracy: 0.9713 - val_loss: 0.0338 - val_accuracy: 0.9952

# %%
model.save('/content/drive/MyDrive/Crack_detection_DB/modelv3.h5')

# %%
loss, accuracy = model.evaluate(test_dataset)
print('Test accuracy :', accuracy)
# Out:
# 13/13 [==============================] - 28s 737ms/step - loss: 0.1807 - accuracy: 0.9850
# Test accuracy : 0.9850000143051147

# %%
# Retrieve a batch of images from the test set
image_batch, label_batch = test_dataset.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch).flatten()

# Apply a sigmoid since our model returns logits
predictions = tf.nn.sigmoid(predictions)
predictions = tf.where(predictions < 0.5, 0, 1)

print('Predictions:\n', predictions.numpy())
print('Labels:\n', label_batch)

plt.figure(figsize=(10, 10))
for i in range(16):
  ax = plt.subplot(4, 4, i + 1)
  plt.imshow(image_batch[i].astype("uint8"))
  plt.title(class_names[predictions[i]])
  plt.axis("off")
# Out:
# Predictions:
#  [0 1 1 1 0 1 1 1 1 1 0 0 1 1 0 1]
# Labels:
#  [0 1 1 1 0 1 1 0 0 1 0 0 0 1 0 1]
